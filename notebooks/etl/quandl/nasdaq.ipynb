# %%
# Due to the file system setting of the Jupyter Notebook, navigate to the package to use infra
# %cd /home/jupyter/quant
# Out:
# /home/jupyter/quant

# %% [markdown]
# ### The following data has been executed and saved. Please be aware of overwritting the existing data.
#
# #### Use notebook `update` to update data for the most recent year

# %%
from datetime import datetime

from yitian.datasource.quandl.nasdaq import NAME, NASDAQ_DATABASE_CODE, DATASET_CODE_MAP

# %%
# Recently executed on
print(datetime.now())
print("======================================================================================================================================================")

db_name = NASDAQ_DATABASE_CODE

for name, ds in DATASET_CODE_MAP.items():
    ds_name = ds
    output_dw_dir = 'equity/nasdaq/{name}'.format(name=name)
    
    # years from 2016 to 2019
    for year in range(2016,2020):
        # %run -i 'notebooks/etl/quandl/extraction.py'
        print("======================================================================================================================================================")
# Out:
# 2020-03-08 18:56:11.635920
# ======================================================================================================================================================
# The start date is set to 2016-01-01 & The end date is set to 2016-12-31
# ('id', 41168791)
# ('dataset_code', 'XQC')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 PM Settlement Value (XQC)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XQC>https://indexes.nasdaqomx.com/Index/Overview/XQC</a>')
# ('refreshed_at', '2020-03-07T06:02:27.171Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2016-12-19')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2016-12-19_2016-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/settlement_value/2016/2016-12-19_2016-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2017-01-01 & The end date is set to 2017-12-31
# ('id', 41168791)
# ('dataset_code', 'XQC')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 PM Settlement Value (XQC)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XQC>https://indexes.nasdaqomx.com/Index/Overview/XQC</a>')
# ('refreshed_at', '2020-03-07T06:02:27.171Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2016-12-19')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2017-01-01_2017-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/settlement_value/2017/2017-01-01_2017-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2018-01-01 & The end date is set to 2018-12-31
# ('id', 41168791)
# ('dataset_code', 'XQC')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 PM Settlement Value (XQC)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XQC>https://indexes.nasdaqomx.com/Index/Overview/XQC</a>')
# ('refreshed_at', '2020-03-07T06:02:27.171Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2016-12-19')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2018-01-01_2018-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/settlement_value/2018/2018-01-01_2018-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2019-01-01 & The end date is set to 2019-12-31
# ('id', 41168791)
# ('dataset_code', 'XQC')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 PM Settlement Value (XQC)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XQC>https://indexes.nasdaqomx.com/Index/Overview/XQC</a>')
# ('refreshed_at', '2020-03-07T06:02:27.171Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2016-12-19')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2019-01-01_2019-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/settlement_value/2019/2019-01-01_2019-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2016-01-01 & The end date is set to 2016-12-31
# ('id', 41168790)
# ('dataset_code', 'XNDXT25NNR')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Notional Net Return Index(XNDXT25NNR)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR</a>')
# ('refreshed_at', '2020-03-07T06:02:27.197Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-04-27')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/quandl/notebooks/etl/quandl/extraction.py in <module>
#      46         raise ValueError("User defined start date {start_date} needs to be larger than "
#      47                          "the oldest available date {oldest_available_date}"
# ---> 48                          .format(start_date=start_date, oldest_available_date=oldest_available_date))
#      49
#      50 if dt.strptime(end_date, "%Y-%m-%d") > dt.strptime(newest_available_date, "%Y-%m-%d"):
#
# ValueError: User defined start date 2016-01-01 needs to be larger than the oldest available date 2017-04-27
# ======================================================================================================================================================
# The start date is set to 2017-01-01 & The end date is set to 2017-12-31
# ('id', 41168790)
# ('dataset_code', 'XNDXT25NNR')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Notional Net Return Index(XNDXT25NNR)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR</a>')
# ('refreshed_at', '2020-03-07T06:02:27.197Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-04-27')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2017-04-27_2017-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/national_net_return_idx/2017/2017-04-27_2017-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2018-01-01 & The end date is set to 2018-12-31
# ('id', 41168790)
# ('dataset_code', 'XNDXT25NNR')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Notional Net Return Index(XNDXT25NNR)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR</a>')
# ('refreshed_at', '2020-03-07T06:02:27.197Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-04-27')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2018-01-01_2018-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/national_net_return_idx/2018/2018-01-01_2018-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2019-01-01 & The end date is set to 2019-12-31
# ('id', 41168790)
# ('dataset_code', 'XNDXT25NNR')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Notional Net Return Index(XNDXT25NNR)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNR</a>')
# ('refreshed_at', '2020-03-07T06:02:27.197Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-04-27')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2019-01-01_2019-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/national_net_return_idx/2019/2019-01-01_2019-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2016-01-01 & The end date is set to 2016-12-31
# ('id', 41168789)
# ('dataset_code', 'XNDXT25NNER')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Net Excess Return Index (XNDXT25NNER)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER</a>')
# ('refreshed_at', '2020-03-07T06:02:27.251Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/quandl/notebooks/etl/quandl/extraction.py in <module>
#      46         raise ValueError("User defined start date {start_date} needs to be larger than "
#      47                          "the oldest available date {oldest_available_date}"
# ---> 48                          .format(start_date=start_date, oldest_available_date=oldest_available_date))
#      49
#      50 if dt.strptime(end_date, "%Y-%m-%d") > dt.strptime(newest_available_date, "%Y-%m-%d"):
#
# ValueError: User defined start date 2016-01-01 needs to be larger than the oldest available date 2017-05-22
# ======================================================================================================================================================
# The start date is set to 2017-01-01 & The end date is set to 2017-12-31
# ('id', 41168789)
# ('dataset_code', 'XNDXT25NNER')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Net Excess Return Index (XNDXT25NNER)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER</a>')
# ('refreshed_at', '2020-03-07T06:02:27.251Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2017-05-22_2017-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/net_excess_return_idx/2017/2017-05-22_2017-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2018-01-01 & The end date is set to 2018-12-31
# ('id', 41168789)
# ('dataset_code', 'XNDXT25NNER')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Net Excess Return Index (XNDXT25NNER)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER</a>')
# ('refreshed_at', '2020-03-07T06:02:27.251Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2018-01-01_2018-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/net_excess_return_idx/2018/2018-01-01_2018-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2019-01-01 & The end date is set to 2019-12-31
# ('id', 41168789)
# ('dataset_code', 'XNDXT25NNER')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Net Excess Return Index (XNDXT25NNER)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25NNER</a>')
# ('refreshed_at', '2020-03-07T06:02:27.251Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2019-01-01_2019-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/net_excess_return_idx/2019/2019-01-01_2019-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2016-01-01 & The end date is set to 2016-12-31
# ('id', 41168788)
# ('dataset_code', 'XNDXT25E')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Excess Return Index (XNDXT25E)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E</a>')
# ('refreshed_at', '2020-03-07T06:02:27.194Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/quandl/notebooks/etl/quandl/extraction.py in <module>
#      46         raise ValueError("User defined start date {start_date} needs to be larger than "
#      47                          "the oldest available date {oldest_available_date}"
# ---> 48                          .format(start_date=start_date, oldest_available_date=oldest_available_date))
#      49
#      50 if dt.strptime(end_date, "%Y-%m-%d") > dt.strptime(newest_available_date, "%Y-%m-%d"):
#
# ValueError: User defined start date 2016-01-01 needs to be larger than the oldest available date 2017-05-22
# ======================================================================================================================================================
# The start date is set to 2017-01-01 & The end date is set to 2017-12-31
# ('id', 41168788)
# ('dataset_code', 'XNDXT25E')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Excess Return Index (XNDXT25E)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E</a>')
# ('refreshed_at', '2020-03-07T06:02:27.194Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2017-05-22_2017-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/excess_return_idx/2017/2017-05-22_2017-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2018-01-01 & The end date is set to 2018-12-31
# ('id', 41168788)
# ('dataset_code', 'XNDXT25E')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Excess Return Index (XNDXT25E)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E</a>')
# ('refreshed_at', '2020-03-07T06:02:27.194Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2018-01-01_2018-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/excess_return_idx/2018/2018-01-01_2018-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2019-01-01 & The end date is set to 2019-12-31
# ('id', 41168788)
# ('dataset_code', 'XNDXT25E')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Excess Return Index (XNDXT25E)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25E</a>')
# ('refreshed_at', '2020-03-07T06:02:27.194Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-22')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2019-01-01_2019-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/excess_return_idx/2019/2019-01-01_2019-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2016-01-01 & The end date is set to 2016-12-31
# ('id', 41168787)
# ('dataset_code', 'XNDXT25')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Total Return Index(XNDXT25)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25</a>')
# ('refreshed_at', '2020-03-07T06:02:27.252Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-01')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/quandl/notebooks/etl/quandl/extraction.py in <module>
#      46         raise ValueError("User defined start date {start_date} needs to be larger than "
#      47                          "the oldest available date {oldest_available_date}"
# ---> 48                          .format(start_date=start_date, oldest_available_date=oldest_available_date))
#      49
#      50 if dt.strptime(end_date, "%Y-%m-%d") > dt.strptime(newest_available_date, "%Y-%m-%d"):
#
# ValueError: User defined start date 2016-01-01 needs to be larger than the oldest available date 2017-05-01
# ======================================================================================================================================================
# The start date is set to 2017-01-01 & The end date is set to 2017-12-31
# ('id', 41168787)
# ('dataset_code', 'XNDXT25')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Total Return Index(XNDXT25)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25</a>')
# ('refreshed_at', '2020-03-07T06:02:27.252Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-01')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2017-05-01_2017-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/total_return_idx/2017/2017-05-01_2017-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2018-01-01 & The end date is set to 2018-12-31
# ('id', 41168787)
# ('dataset_code', 'XNDXT25')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Total Return Index(XNDXT25)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25</a>')
# ('refreshed_at', '2020-03-07T06:02:27.252Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-01')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2018-01-01_2018-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/total_return_idx/2018/2018-01-01_2018-12-31_daily.csv
# ======================================================================================================================================================
# The start date is set to 2019-01-01 & The end date is set to 2019-12-31
# ('id', 41168787)
# ('dataset_code', 'XNDXT25')
# ('database_code', 'NASDAQOMX')
# ('name', 'NASDAQ-100 Target 25 Total Return Index(XNDXT25)')
# ('description', 'For detailed information, see <a href=https://indexes.nasdaqomx.com/Index/Overview/XNDXT25>https://indexes.nasdaqomx.com/Index/Overview/XNDXT25</a>')
# ('refreshed_at', '2020-03-07T06:02:27.252Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '2017-05-01')
# ('column_names', ['Trade Date', 'Index Value', 'High', 'Low', 'Total Market Value', 'Dividend Market Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 10471)
# 2019-01-01_2019-12-31_daily.csv has been overwrite to gs://zhongyuan-dw/equity/nasdaq/total_return_idx/2019/2019-01-01_2019-12-31_daily.csv
# ======================================================================================================================================================
