# %%
# Due to the file system setting of the Jupyter Notebook, navigate to the package to use infra
# %cd /home/jupyter/quant
# Out:
# /home/jupyter/quant

# %% [markdown]
# ### The following data has been executed and saved. Please be aware of overwritting the existing data.
#
# #### Use notebook `update` to update data for the most recent year

# %%
from datetime import datetime

from yitian.datasource import INTEREST_RATE_AND_FIXED_INCOME
from yitian.datasource.quandl.fed import NAME, FED_DATABASE_CODE, DATASET_CODE_MAP

# %%
# Recently executed on
print(datetime.now())
print("======================================================================================================================================================")

data_category = INTEREST_RATE_AND_FIXED_INCOME
db_name = FED_DATABASE_CODE

for name, desc in DATASET_CODE_MAP.items():
    ds_name = name
    print("Extracting {ds_name} : {desc}".format(ds_name=ds_name, desc=desc))
    
    # years from 1961 to 2019
    for year in range(1961,2020):
        # %run -i 'notebooks/etl/quandl/load_add_info.py'
        print("======================================================================================================================================================")
# Out:
# 2020-03-15 20:18:49.431880
# ======================================================================================================================================================
# Extracting svenpy : us_treasury_par_yield_curve
# Start date (1961-01-01) & End date (1961-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1961 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1961/history.csv
# ======================================================================================================================================================
# Start date (1962-01-01) & End date (1962-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1962 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1962/history.csv
# ======================================================================================================================================================
# Start date (1963-01-01) & End date (1963-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1963 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1963/history.csv
# ======================================================================================================================================================
# Start date (1964-01-01) & End date (1964-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1964 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1964/history.csv
# ======================================================================================================================================================
# Start date (1965-01-01) & End date (1965-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1965 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1965/history.csv
# ======================================================================================================================================================
# Start date (1966-01-01) & End date (1966-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1966 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1966/history.csv
# ======================================================================================================================================================
# Start date (1967-01-01) & End date (1967-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1967 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1967/history.csv
# ======================================================================================================================================================
# Start date (1968-01-01) & End date (1968-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1968 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1968/history.csv
# ======================================================================================================================================================
# Start date (1969-01-01) & End date (1969-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1969 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1969/history.csv
# ======================================================================================================================================================
# Start date (1970-01-01) & End date (1970-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1970 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1970/history.csv
# ======================================================================================================================================================
# Start date (1971-01-01) & End date (1971-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1971 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1971/history.csv
# ======================================================================================================================================================
# Start date (1972-01-01) & End date (1972-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1972 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1972/history.csv
# ======================================================================================================================================================
# Start date (1973-01-01) & End date (1973-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1973 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1973/history.csv
# ======================================================================================================================================================
# Start date (1974-01-01) & End date (1974-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1974 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1974/history.csv
# ======================================================================================================================================================
# Start date (1975-01-01) & End date (1975-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1975 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1975/history.csv
# ======================================================================================================================================================
# Start date (1976-01-01) & End date (1976-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1976 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1976/history.csv
# ======================================================================================================================================================
# Start date (1977-01-01) & End date (1977-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1977 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1977/history.csv
# ======================================================================================================================================================
# Start date (1978-01-01) & End date (1978-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1978 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1978/history.csv
# ======================================================================================================================================================
# Start date (1979-01-01) & End date (1979-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1979 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1979/history.csv
# ======================================================================================================================================================
# Start date (1980-01-01) & End date (1980-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1980 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1980/history.csv
# ======================================================================================================================================================
# Start date (1981-01-01) & End date (1981-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1981 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1981/history.csv
# ======================================================================================================================================================
# Start date (1982-01-01) & End date (1982-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1982 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1982/history.csv
# ======================================================================================================================================================
# Start date (1983-01-01) & End date (1983-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1983 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1983/history.csv
# ======================================================================================================================================================
# Start date (1984-01-01) & End date (1984-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1984 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1984/history.csv
# ======================================================================================================================================================
# Start date (1985-01-01) & End date (1985-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1985 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1985/history.csv
# ======================================================================================================================================================
# Start date (1986-01-01) & End date (1986-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1986 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1986/history.csv
# ======================================================================================================================================================
# Start date (1987-01-01) & End date (1987-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1987 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1987/history.csv
# ======================================================================================================================================================
# Start date (1988-01-01) & End date (1988-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1988 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1988/history.csv
# ======================================================================================================================================================
# Start date (1989-01-01) & End date (1989-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1989 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1989/history.csv
# ======================================================================================================================================================
# Start date (1990-01-01) & End date (1990-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / svenpy in 1990 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/svenpy/1990/history.csv
# ======================================================================================================================================================
# Start date (1991-01-01) & End date (1991-12-31)
# ('id', 14468012)
# ('dataset_code', 'SVENPY')
# ('database_code', 'FED')
# ('name', 'US Treasury Par Yield Curve')
# ('description', 'These yield curves are an off-the-run Treasury yield curve based on a large set of outstanding Treasury notes and bonds, and are based on a coupon-equivalent compounding convention. Values are daily estimates of the yield curve from 1961 for the entire maturity range spanned by outstanding Treasury securities.<br><br>More detailed information is available at <a href=http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf>http://www.federalreserve.gov/pubs/feds/2006/200628/200628pap.pdf</a>')
# ('refreshed_at', '2020-03-13T04:06:13.015Z')
# ('newest_available_date', '2020-03-06')
# ('oldest_available_date', '1961-06-14')
# ('column_names', ['Date', 'SVENPY01', 'SVENPY02', 'SVENPY03', 'SVENPY04', 'SVENPY05', 'SVENPY06', 'SVENPY07', 'SVENPY08', 'SVENPY09', 'SVENPY10', 'SVENPY11', 'SVENPY12', 'SVENPY13', 'SVENPY14', 'SVENPY15', 'SVENPY16', 'SVENPY17', 'SVENPY18', 'SVENPY19', 'SVENPY20', 'SVENPY21', 'SVENPY22', 'SVENPY23', 'SVENPY24', 'SVENPY25', 'SVENPY26', 'SVENPY27', 'SVENPY28', 'SVENPY29', 'SVENPY30'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# ...
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2013 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2013/history.csv
# ======================================================================================================================================================
# Start date (2014-01-01) & End date (2014-12-31)
# ('id', 23761126)
# ('dataset_code', 'TIPSY')
# ('database_code', 'FED')
# ('name', 'TIPS Yield Curve and Inflation Compensation')
# ('description', 'Federal Reserve yield curve of index-linked debt. Daily frequency. More detailed information available at http://www.federalreserve.gov/pubs/feds/2008/200805/200805abs.html')
# ('refreshed_at', '2020-03-13T04:10:22.903Z')
# ('newest_available_date', '2019-10-25')
# ('oldest_available_date', '1999-01-04')
# ('column_names', ['Date', 'TIPSY02', 'TIPSY03', 'TIPSY04', 'TIPSY05', 'TIPSY06', 'TIPSY07', 'TIPSY08', 'TIPSY09', 'TIPSY10', 'TIPSY11', 'TIPSY12', 'TIPSY13', 'TIPSY14', 'TIPSY15', 'TIPSY16', 'TIPSY17', 'TIPSY18', 'TIPSY19', 'TIPSY20', 'TIPSPY02', 'TIPSPY03', 'TIPSPY04', 'TIPSPY05', 'TIPSPY06', 'TIPSPY07', 'TIPSPY08', 'TIPSPY09', 'TIPSPY10', 'TIPSPY11', 'TIPSPY12', 'TIPSPY13', 'TIPSPY14', 'TIPSPY15', 'TIPSPY16', 'TIPSPY17', 'TIPSPY18', 'TIPSPY19', 'TIPSPY20', 'TIPSF02', 'TIPSF03', 'TIPSF04', 'TIPSF05', 'TIPSF06', 'TIPSF07', 'TIPSF08', 'TIPSF09', 'TIPSF10', 'TIPSF11', 'TIPSF12', 'TIPSF13', 'TIPSF14', 'TIPSF15', 'TIPSF16', 'TIPSF17', 'TIPSF18', 'TIPSF19', 'TIPSF20', 'TIPS1F04', 'TIPS1F09', 'TIPS5F5', 'BKEVENY02', 'BKEVENY03', 'BKEVENY04', 'BKEVENY05', 'BKEVENY06', 'BKEVENY07', 'BKEVENY08', 'BKEVENY09', 'BKEVENY10', 'BKEVENY11', 'BKEVENY12', 'BKEVENY13', 'BKEVENY14', 'BKEVENY15', 'BKEVENY16', 'BKEVENY17', 'BKEVENY18', 'BKEVENY19', 'BKEVENY20', 'BKEVEN02', 'BKEVEN03', 'BKEVEN04', 'BKEVEN05', 'BKEVEN06', 'BKEVEN07', 'BKEVEN08', 'BKEVEN09', 'BKEVEN10', 'BKEVEN11', 'BKEVEN12', 'BKEVEN13', 'BKEVEN14', 'BKEVEN15', 'BKEVEN16', 'BKEVEN17', 'BKEVEN18', 'BKEVEN19', 'BKEVEN20', 'BKEVENF02', 'BKEVENF03', 'BKEVENF04', 'BKEVENF05', 'BKEVENF06', 'BKEVENF07', 'BKEVENF08', 'BKEVENF09', 'BKEVENF10', 'BKEVENF11', 'BKEVENF12', 'BKEVENF13', 'BKEVENF14', 'BKEVENF15', 'BKEVENF16', 'BKEVENF17', 'BKEVENF18', 'BKEVENF19', 'BKEVENF20', 'BKEVEN1F4', 'BKEVEN1F9', 'BKEVEN5F5', 'BETA0', 'BETA1', 'BETA2', 'BETA3', 'TAU1', 'TAU2'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2014 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2014/history.csv
# ======================================================================================================================================================
# Start date (2015-01-01) & End date (2015-12-31)
# ('id', 23761126)
# ('dataset_code', 'TIPSY')
# ('database_code', 'FED')
# ('name', 'TIPS Yield Curve and Inflation Compensation')
# ('description', 'Federal Reserve yield curve of index-linked debt. Daily frequency. More detailed information available at http://www.federalreserve.gov/pubs/feds/2008/200805/200805abs.html')
# ('refreshed_at', '2020-03-13T04:10:22.903Z')
# ('newest_available_date', '2019-10-25')
# ('oldest_available_date', '1999-01-04')
# ('column_names', ['Date', 'TIPSY02', 'TIPSY03', 'TIPSY04', 'TIPSY05', 'TIPSY06', 'TIPSY07', 'TIPSY08', 'TIPSY09', 'TIPSY10', 'TIPSY11', 'TIPSY12', 'TIPSY13', 'TIPSY14', 'TIPSY15', 'TIPSY16', 'TIPSY17', 'TIPSY18', 'TIPSY19', 'TIPSY20', 'TIPSPY02', 'TIPSPY03', 'TIPSPY04', 'TIPSPY05', 'TIPSPY06', 'TIPSPY07', 'TIPSPY08', 'TIPSPY09', 'TIPSPY10', 'TIPSPY11', 'TIPSPY12', 'TIPSPY13', 'TIPSPY14', 'TIPSPY15', 'TIPSPY16', 'TIPSPY17', 'TIPSPY18', 'TIPSPY19', 'TIPSPY20', 'TIPSF02', 'TIPSF03', 'TIPSF04', 'TIPSF05', 'TIPSF06', 'TIPSF07', 'TIPSF08', 'TIPSF09', 'TIPSF10', 'TIPSF11', 'TIPSF12', 'TIPSF13', 'TIPSF14', 'TIPSF15', 'TIPSF16', 'TIPSF17', 'TIPSF18', 'TIPSF19', 'TIPSF20', 'TIPS1F04', 'TIPS1F09', 'TIPS5F5', 'BKEVENY02', 'BKEVENY03', 'BKEVENY04', 'BKEVENY05', 'BKEVENY06', 'BKEVENY07', 'BKEVENY08', 'BKEVENY09', 'BKEVENY10', 'BKEVENY11', 'BKEVENY12', 'BKEVENY13', 'BKEVENY14', 'BKEVENY15', 'BKEVENY16', 'BKEVENY17', 'BKEVENY18', 'BKEVENY19', 'BKEVENY20', 'BKEVEN02', 'BKEVEN03', 'BKEVEN04', 'BKEVEN05', 'BKEVEN06', 'BKEVEN07', 'BKEVEN08', 'BKEVEN09', 'BKEVEN10', 'BKEVEN11', 'BKEVEN12', 'BKEVEN13', 'BKEVEN14', 'BKEVEN15', 'BKEVEN16', 'BKEVEN17', 'BKEVEN18', 'BKEVEN19', 'BKEVEN20', 'BKEVENF02', 'BKEVENF03', 'BKEVENF04', 'BKEVENF05', 'BKEVENF06', 'BKEVENF07', 'BKEVENF08', 'BKEVENF09', 'BKEVENF10', 'BKEVENF11', 'BKEVENF12', 'BKEVENF13', 'BKEVENF14', 'BKEVENF15', 'BKEVENF16', 'BKEVENF17', 'BKEVENF18', 'BKEVENF19', 'BKEVENF20', 'BKEVEN1F4', 'BKEVEN1F9', 'BKEVEN5F5', 'BETA0', 'BETA1', 'BETA2', 'BETA3', 'TAU1', 'TAU2'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2015 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2015/history.csv
# ======================================================================================================================================================
# Start date (2016-01-01) & End date (2016-12-31)
# ('id', 23761126)
# ('dataset_code', 'TIPSY')
# ('database_code', 'FED')
# ('name', 'TIPS Yield Curve and Inflation Compensation')
# ('description', 'Federal Reserve yield curve of index-linked debt. Daily frequency. More detailed information available at http://www.federalreserve.gov/pubs/feds/2008/200805/200805abs.html')
# ('refreshed_at', '2020-03-13T04:10:22.903Z')
# ('newest_available_date', '2019-10-25')
# ('oldest_available_date', '1999-01-04')
# ('column_names', ['Date', 'TIPSY02', 'TIPSY03', 'TIPSY04', 'TIPSY05', 'TIPSY06', 'TIPSY07', 'TIPSY08', 'TIPSY09', 'TIPSY10', 'TIPSY11', 'TIPSY12', 'TIPSY13', 'TIPSY14', 'TIPSY15', 'TIPSY16', 'TIPSY17', 'TIPSY18', 'TIPSY19', 'TIPSY20', 'TIPSPY02', 'TIPSPY03', 'TIPSPY04', 'TIPSPY05', 'TIPSPY06', 'TIPSPY07', 'TIPSPY08', 'TIPSPY09', 'TIPSPY10', 'TIPSPY11', 'TIPSPY12', 'TIPSPY13', 'TIPSPY14', 'TIPSPY15', 'TIPSPY16', 'TIPSPY17', 'TIPSPY18', 'TIPSPY19', 'TIPSPY20', 'TIPSF02', 'TIPSF03', 'TIPSF04', 'TIPSF05', 'TIPSF06', 'TIPSF07', 'TIPSF08', 'TIPSF09', 'TIPSF10', 'TIPSF11', 'TIPSF12', 'TIPSF13', 'TIPSF14', 'TIPSF15', 'TIPSF16', 'TIPSF17', 'TIPSF18', 'TIPSF19', 'TIPSF20', 'TIPS1F04', 'TIPS1F09', 'TIPS5F5', 'BKEVENY02', 'BKEVENY03', 'BKEVENY04', 'BKEVENY05', 'BKEVENY06', 'BKEVENY07', 'BKEVENY08', 'BKEVENY09', 'BKEVENY10', 'BKEVENY11', 'BKEVENY12', 'BKEVENY13', 'BKEVENY14', 'BKEVENY15', 'BKEVENY16', 'BKEVENY17', 'BKEVENY18', 'BKEVENY19', 'BKEVENY20', 'BKEVEN02', 'BKEVEN03', 'BKEVEN04', 'BKEVEN05', 'BKEVEN06', 'BKEVEN07', 'BKEVEN08', 'BKEVEN09', 'BKEVEN10', 'BKEVEN11', 'BKEVEN12', 'BKEVEN13', 'BKEVEN14', 'BKEVEN15', 'BKEVEN16', 'BKEVEN17', 'BKEVEN18', 'BKEVEN19', 'BKEVEN20', 'BKEVENF02', 'BKEVENF03', 'BKEVENF04', 'BKEVENF05', 'BKEVENF06', 'BKEVENF07', 'BKEVENF08', 'BKEVENF09', 'BKEVENF10', 'BKEVENF11', 'BKEVENF12', 'BKEVENF13', 'BKEVENF14', 'BKEVENF15', 'BKEVENF16', 'BKEVENF17', 'BKEVENF18', 'BKEVENF19', 'BKEVENF20', 'BKEVEN1F4', 'BKEVEN1F9', 'BKEVEN5F5', 'BETA0', 'BETA1', 'BETA2', 'BETA3', 'TAU1', 'TAU2'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2016 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2016/history.csv
# ======================================================================================================================================================
# Start date (2017-01-01) & End date (2017-12-31)
# ('id', 23761126)
# ('dataset_code', 'TIPSY')
# ('database_code', 'FED')
# ('name', 'TIPS Yield Curve and Inflation Compensation')
# ('description', 'Federal Reserve yield curve of index-linked debt. Daily frequency. More detailed information available at http://www.federalreserve.gov/pubs/feds/2008/200805/200805abs.html')
# ('refreshed_at', '2020-03-13T04:10:22.903Z')
# ('newest_available_date', '2019-10-25')
# ('oldest_available_date', '1999-01-04')
# ('column_names', ['Date', 'TIPSY02', 'TIPSY03', 'TIPSY04', 'TIPSY05', 'TIPSY06', 'TIPSY07', 'TIPSY08', 'TIPSY09', 'TIPSY10', 'TIPSY11', 'TIPSY12', 'TIPSY13', 'TIPSY14', 'TIPSY15', 'TIPSY16', 'TIPSY17', 'TIPSY18', 'TIPSY19', 'TIPSY20', 'TIPSPY02', 'TIPSPY03', 'TIPSPY04', 'TIPSPY05', 'TIPSPY06', 'TIPSPY07', 'TIPSPY08', 'TIPSPY09', 'TIPSPY10', 'TIPSPY11', 'TIPSPY12', 'TIPSPY13', 'TIPSPY14', 'TIPSPY15', 'TIPSPY16', 'TIPSPY17', 'TIPSPY18', 'TIPSPY19', 'TIPSPY20', 'TIPSF02', 'TIPSF03', 'TIPSF04', 'TIPSF05', 'TIPSF06', 'TIPSF07', 'TIPSF08', 'TIPSF09', 'TIPSF10', 'TIPSF11', 'TIPSF12', 'TIPSF13', 'TIPSF14', 'TIPSF15', 'TIPSF16', 'TIPSF17', 'TIPSF18', 'TIPSF19', 'TIPSF20', 'TIPS1F04', 'TIPS1F09', 'TIPS5F5', 'BKEVENY02', 'BKEVENY03', 'BKEVENY04', 'BKEVENY05', 'BKEVENY06', 'BKEVENY07', 'BKEVENY08', 'BKEVENY09', 'BKEVENY10', 'BKEVENY11', 'BKEVENY12', 'BKEVENY13', 'BKEVENY14', 'BKEVENY15', 'BKEVENY16', 'BKEVENY17', 'BKEVENY18', 'BKEVENY19', 'BKEVENY20', 'BKEVEN02', 'BKEVEN03', 'BKEVEN04', 'BKEVEN05', 'BKEVEN06', 'BKEVEN07', 'BKEVEN08', 'BKEVEN09', 'BKEVEN10', 'BKEVEN11', 'BKEVEN12', 'BKEVEN13', 'BKEVEN14', 'BKEVEN15', 'BKEVEN16', 'BKEVEN17', 'BKEVEN18', 'BKEVEN19', 'BKEVEN20', 'BKEVENF02', 'BKEVENF03', 'BKEVENF04', 'BKEVENF05', 'BKEVENF06', 'BKEVENF07', 'BKEVENF08', 'BKEVENF09', 'BKEVENF10', 'BKEVENF11', 'BKEVENF12', 'BKEVENF13', 'BKEVENF14', 'BKEVENF15', 'BKEVENF16', 'BKEVENF17', 'BKEVENF18', 'BKEVENF19', 'BKEVENF20', 'BKEVEN1F4', 'BKEVEN1F9', 'BKEVEN5F5', 'BETA0', 'BETA1', 'BETA2', 'BETA3', 'TAU1', 'TAU2'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2017 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2017/history.csv
# ======================================================================================================================================================
# Start date (2018-01-01) & End date (2018-12-31)
# ('id', 23761126)
# ('dataset_code', 'TIPSY')
# ('database_code', 'FED')
# ('name', 'TIPS Yield Curve and Inflation Compensation')
# ('description', 'Federal Reserve yield curve of index-linked debt. Daily frequency. More detailed information available at http://www.federalreserve.gov/pubs/feds/2008/200805/200805abs.html')
# ('refreshed_at', '2020-03-13T04:10:22.903Z')
# ('newest_available_date', '2019-10-25')
# ('oldest_available_date', '1999-01-04')
# ('column_names', ['Date', 'TIPSY02', 'TIPSY03', 'TIPSY04', 'TIPSY05', 'TIPSY06', 'TIPSY07', 'TIPSY08', 'TIPSY09', 'TIPSY10', 'TIPSY11', 'TIPSY12', 'TIPSY13', 'TIPSY14', 'TIPSY15', 'TIPSY16', 'TIPSY17', 'TIPSY18', 'TIPSY19', 'TIPSY20', 'TIPSPY02', 'TIPSPY03', 'TIPSPY04', 'TIPSPY05', 'TIPSPY06', 'TIPSPY07', 'TIPSPY08', 'TIPSPY09', 'TIPSPY10', 'TIPSPY11', 'TIPSPY12', 'TIPSPY13', 'TIPSPY14', 'TIPSPY15', 'TIPSPY16', 'TIPSPY17', 'TIPSPY18', 'TIPSPY19', 'TIPSPY20', 'TIPSF02', 'TIPSF03', 'TIPSF04', 'TIPSF05', 'TIPSF06', 'TIPSF07', 'TIPSF08', 'TIPSF09', 'TIPSF10', 'TIPSF11', 'TIPSF12', 'TIPSF13', 'TIPSF14', 'TIPSF15', 'TIPSF16', 'TIPSF17', 'TIPSF18', 'TIPSF19', 'TIPSF20', 'TIPS1F04', 'TIPS1F09', 'TIPS5F5', 'BKEVENY02', 'BKEVENY03', 'BKEVENY04', 'BKEVENY05', 'BKEVENY06', 'BKEVENY07', 'BKEVENY08', 'BKEVENY09', 'BKEVENY10', 'BKEVENY11', 'BKEVENY12', 'BKEVENY13', 'BKEVENY14', 'BKEVENY15', 'BKEVENY16', 'BKEVENY17', 'BKEVENY18', 'BKEVENY19', 'BKEVENY20', 'BKEVEN02', 'BKEVEN03', 'BKEVEN04', 'BKEVEN05', 'BKEVEN06', 'BKEVEN07', 'BKEVEN08', 'BKEVEN09', 'BKEVEN10', 'BKEVEN11', 'BKEVEN12', 'BKEVEN13', 'BKEVEN14', 'BKEVEN15', 'BKEVEN16', 'BKEVEN17', 'BKEVEN18', 'BKEVEN19', 'BKEVEN20', 'BKEVENF02', 'BKEVENF03', 'BKEVENF04', 'BKEVENF05', 'BKEVENF06', 'BKEVENF07', 'BKEVENF08', 'BKEVENF09', 'BKEVENF10', 'BKEVENF11', 'BKEVENF12', 'BKEVENF13', 'BKEVENF14', 'BKEVENF15', 'BKEVENF16', 'BKEVENF17', 'BKEVENF18', 'BKEVENF19', 'BKEVENF20', 'BKEVEN1F4', 'BKEVEN1F9', 'BKEVEN5F5', 'BETA0', 'BETA1', 'BETA2', 'BETA3', 'TAU1', 'TAU2'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2018 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2018/history.csv
# ======================================================================================================================================================
# Start date (2019-01-01) & End date (2019-12-31)
# ('id', 23761126)
# ('dataset_code', 'TIPSY')
# ('database_code', 'FED')
# ('name', 'TIPS Yield Curve and Inflation Compensation')
# ('description', 'Federal Reserve yield curve of index-linked debt. Daily frequency. More detailed information available at http://www.federalreserve.gov/pubs/feds/2008/200805/200805abs.html')
# ('refreshed_at', '2020-03-13T04:10:22.903Z')
# ('newest_available_date', '2019-10-25')
# ('oldest_available_date', '1999-01-04')
# ('column_names', ['Date', 'TIPSY02', 'TIPSY03', 'TIPSY04', 'TIPSY05', 'TIPSY06', 'TIPSY07', 'TIPSY08', 'TIPSY09', 'TIPSY10', 'TIPSY11', 'TIPSY12', 'TIPSY13', 'TIPSY14', 'TIPSY15', 'TIPSY16', 'TIPSY17', 'TIPSY18', 'TIPSY19', 'TIPSY20', 'TIPSPY02', 'TIPSPY03', 'TIPSPY04', 'TIPSPY05', 'TIPSPY06', 'TIPSPY07', 'TIPSPY08', 'TIPSPY09', 'TIPSPY10', 'TIPSPY11', 'TIPSPY12', 'TIPSPY13', 'TIPSPY14', 'TIPSPY15', 'TIPSPY16', 'TIPSPY17', 'TIPSPY18', 'TIPSPY19', 'TIPSPY20', 'TIPSF02', 'TIPSF03', 'TIPSF04', 'TIPSF05', 'TIPSF06', 'TIPSF07', 'TIPSF08', 'TIPSF09', 'TIPSF10', 'TIPSF11', 'TIPSF12', 'TIPSF13', 'TIPSF14', 'TIPSF15', 'TIPSF16', 'TIPSF17', 'TIPSF18', 'TIPSF19', 'TIPSF20', 'TIPS1F04', 'TIPS1F09', 'TIPS5F5', 'BKEVENY02', 'BKEVENY03', 'BKEVENY04', 'BKEVENY05', 'BKEVENY06', 'BKEVENY07', 'BKEVENY08', 'BKEVENY09', 'BKEVENY10', 'BKEVENY11', 'BKEVENY12', 'BKEVENY13', 'BKEVENY14', 'BKEVENY15', 'BKEVENY16', 'BKEVENY17', 'BKEVENY18', 'BKEVENY19', 'BKEVENY20', 'BKEVEN02', 'BKEVEN03', 'BKEVEN04', 'BKEVEN05', 'BKEVEN06', 'BKEVEN07', 'BKEVEN08', 'BKEVEN09', 'BKEVEN10', 'BKEVEN11', 'BKEVEN12', 'BKEVEN13', 'BKEVEN14', 'BKEVEN15', 'BKEVEN16', 'BKEVEN17', 'BKEVEN18', 'BKEVEN19', 'BKEVEN20', 'BKEVENF02', 'BKEVENF03', 'BKEVENF04', 'BKEVENF05', 'BKEVENF06', 'BKEVENF07', 'BKEVENF08', 'BKEVENF09', 'BKEVENF10', 'BKEVENF11', 'BKEVENF12', 'BKEVENF13', 'BKEVENF14', 'BKEVENF15', 'BKEVENF16', 'BKEVENF17', 'BKEVENF18', 'BKEVENF19', 'BKEVENF20', 'BKEVEN1F4', 'BKEVEN1F9', 'BKEVEN5F5', 'BETA0', 'BETA1', 'BETA2', 'BETA3', 'TAU1', 'TAU2'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 59)
# FED / tipsy in 2019 has been overwrite to gs://zhongyuan-dw/interest_rate_and_fix_income/fed/tipsy/2019/history.csv
# ======================================================================================================================================================
