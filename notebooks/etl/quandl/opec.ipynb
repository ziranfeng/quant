# %%
# Due to the file system setting of the Jupyter Notebook, navigate to the package to use infra
# %cd /home/jupyter/quant
# Out:
# /home/jupyter/quant

# %% [markdown]
# ### The following data has been executed and saved. Please be aware of overwritting the existing data.
#
# #### Use notebook `update` to update data for the most recent year

# %%
from datetime import datetime

from yitian.datasource import COMMODITY
from yitian.datasource.quandl.opec import NAME, OPEC_DATABASE_CODE, OPEC_DATASET_CODE

# %% [markdown]
# OPEC Historical Data from 2000 to 2019

# %%
# Recent executed on
print(datetime.now())
print("======================================================================================================================================================")

data_category = COMMODITY
db_name = OPEC_DATABASE_CODE
ds_name = OPEC_DATASET_CODE

# years from 2003 to 2019
for year in range(2003,2020):
    # %run -i 'notebooks/etl/quandl/update_additional_info.py'
    print("======================================================================================================================================================")
# Out:
# 2020-03-15 20:14:34.681021
# ======================================================================================================================================================
# Start date (2003-01-01) & End date (2003-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2003 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2003/history.csv
# ======================================================================================================================================================
# Start date (2004-01-01) & End date (2004-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2004 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2004/history.csv
# ======================================================================================================================================================
# Start date (2005-01-01) & End date (2005-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2005 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2005/history.csv
# ======================================================================================================================================================
# Start date (2006-01-01) & End date (2006-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2006 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2006/history.csv
# ======================================================================================================================================================
# Start date (2007-01-01) & End date (2007-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2007 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2007/history.csv
# ======================================================================================================================================================
# Start date (2008-01-01) & End date (2008-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2008 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2008/history.csv
# ======================================================================================================================================================
# Start date (2009-01-01) & End date (2009-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2009 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2009/history.csv
# ======================================================================================================================================================
# Start date (2010-01-01) & End date (2010-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2010 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2010/history.csv
# ======================================================================================================================================================
# Start date (2011-01-01) & End date (2011-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2011 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2011/history.csv
# ======================================================================================================================================================
# Start date (2012-01-01) & End date (2012-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2012 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2012/history.csv
# ======================================================================================================================================================
# Start date (2013-01-01) & End date (2013-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2013 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2013/history.csv
# ======================================================================================================================================================
# Start date (2014-01-01) & End date (2014-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2014 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2014/history.csv
# ======================================================================================================================================================
# Start date (2015-01-01) & End date (2015-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2015 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2015/history.csv
# ======================================================================================================================================================
# Start date (2016-01-01) & End date (2016-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2016 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2016/history.csv
# ======================================================================================================================================================
# Start date (2017-01-01) & End date (2017-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2017 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2017/history.csv
# ======================================================================================================================================================
# Start date (2018-01-01) & End date (2018-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2018 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2018/history.csv
# ======================================================================================================================================================
# Start date (2019-01-01) & End date (2019-12-31)
# ('id', 2288715)
# ('dataset_code', 'ORB')
# ('database_code', 'OPEC')
# ('name', 'OPEC Crude Oil Price')
# ('description', 'Reference Price for the OPEC Crude Oil Basket.  Currently includes: Saharan Blend (Algeria), Girassol (Angola), Oriente (Ecuador), Iran Heavy (Islamic Republic of Iran), Basra Light (Iraq), Kuwait Export (Kuwait), Es Sider (Libya), Bonny Light (Nigeria), Qatar Marine (Qatar), Arab Light (Saudi Arabia), Murban (UAE) and Merey (Venezuela).')
# ('refreshed_at', '2020-03-13T12:32:05.707Z')
# ('newest_available_date', '2020-03-12')
# ('oldest_available_date', '2003-01-02')
# ('column_names', ['Date', 'Value'])
# ('frequency', 'daily')
# ('type', 'Time Series')
# ('premium', False)
# ('database_id', 381)
# OPEC / ORB in 2019 has been overwrite to gs://zhongyuan-dw/commodity/opec/orb/2019/history.csv
# ======================================================================================================================================================
